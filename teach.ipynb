# %% [markdown]
# Python数值运算

# %%
1+2
# Out:
# 3

# %%
2+2
1+1
# Out:
# 2

# %%
print(2+2)
1+1
# Out:
# 4
# 2

# %%
4*5
# Out:
# 20

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
tang=3

# %%
tang
# Out:
# 3

# %%
type(tang)
# Out:
# int

# %%
tang1=1.5

# %%
type(tang1)
# Out:
# float

# %%
tang2=int(tang1)

# %%
type(tang2)
# Out:
# int

# %%
tang_str='123'

# %%
type(tang_str)
# Out:
# str

# %%
int(tang_str)
# Out:
# 123

# %%
tang2_str='tang'

# %%
int(tang2_str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 int(tang2_str)
#
# ValueError: invalid literal for int() with base 10: 'tang'

# %% [markdown]
# 原因:字符串不能强制转换为数值

# %%
str(123)
# Out:
# '123'

# %%
abs(15.6)
# Out:
# 15.6

# %% [markdown]
# abs取绝对值

# %%
round(15.6)
# Out:
# 16

# %%
round(15.4)
# Out:
# 15

# %% [markdown]
# round四舍五入

# %%
min(1,2,3,)
# Out:
# 1

# %%
max(1,2,3)
# Out:
# 3

# %%
1.3e5
# Out:
# 130000.0

# %%
1.3e-05
# Out:
# 1.3e-05

# %%
0xff
# Out:
# 255

# %%
tang=True

# %%
tang
# Out:
# True

# %%
type(tang)
# Out:
# bool
